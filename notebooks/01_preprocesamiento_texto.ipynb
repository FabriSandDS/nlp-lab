# %% [markdown]
# El preprocesamiento de texto es el conjunto de pasos previos que aplicamos a un texto antes de poder usarlo en tareas de análisis, clasificación o entrenamiento de modelos de NLP.
#
# 🎯 Objetivo del preprocesamiento:
# Transformar el texto crudo en una versión más limpia, estandarizada y útil para análisis.

# %% [markdown]
# Primera etapa del preprocesamiento:
# 🧽 ¿Qué es la normalización de texto?
# Es el proceso de transformar el texto crudo en una forma estándar y coherente.
# Lo hacemos para que los modelos no se confundan con variaciones irrelevantes (como “Hola” vs “hola”) y para facilitar los siguientes pasos del pipeline.

# %%
with open (r'C:\Proyectos_DS\nlp-lab\data\Caballero_Cap_1.txt', 'r', encoding='utf-8') as archivo:
    texto = archivo.read()
print(texto[:500])
# Out:
# Hace ya mucho tiempo, en una tierra muy lejana, vivía un caballero que pensaba que era bueno, generoso y
# amoroso. Hacía todo lo que suelen hacer los caballeros buenos, generosos y amorosos. Luchaba contra sus
# enemigos, que era malos, mezquinos y odiosos. Mataba a dragones y rescataba a damiselas en apuros.
# Cuando en el asunto de la caballería había crisis, tenía la mala costumbre de rescatar damiselas incluso
# cuando ellas no deseaban ser rescatadas y, debido a esto, aunque muchas damas le estaba

# %%
texto_normalizado = texto

# %%
import unicodedata
import re

def eliminar_tildes(texto_normalizado):
    texto_normalizado = unicodedata.normalize('NFD', texto_normalizado)
    texto_normalizado = ''.join(
        c for c in texto_normalizado if unicodedata.category(c) != 'Mn'
    )
    return texto_normalizado

# %%
texto_normalizado = eliminar_tildes(texto_normalizado)

print(texto_normalizado[:500])
# Out:
# Hace ya mucho tiempo, en una tierra muy lejana, vivia un caballero que pensaba que era bueno, generoso y
# amoroso. Hacia todo lo que suelen hacer los caballeros buenos, generosos y amorosos. Luchaba contra sus
# enemigos, que era malos, mezquinos y odiosos. Mataba a dragones y rescataba a damiselas en apuros.
# Cuando en el asunto de la caballeria habia crisis, tenia la mala costumbre de rescatar damiselas incluso
# cuando ellas no deseaban ser rescatadas y, debido a esto, aunque muchas damas le estaba

# %%
texto_normalizado = re.sub(r'[^\w\s]', '', texto_normalizado)
print(texto_normalizado[:500])
#Esto elimina todo caracter que no sea alfanumerico o un espacio
# Out:
# Hace ya mucho tiempo en una tierra muy lejana vivia un caballero que pensaba que era bueno generoso y
# amoroso Hacia todo lo que suelen hacer los caballeros buenos generosos y amorosos Luchaba contra sus
# enemigos que era malos mezquinos y odiosos Mataba a dragones y rescataba a damiselas en apuros
# Cuando en el asunto de la caballeria habia crisis tenia la mala costumbre de rescatar damiselas incluso
# cuando ellas no deseaban ser rescatadas y debido a esto aunque muchas damas le estaban agradecidas

# %%
texto_normalizado = re.sub(r'\s+', ' ', texto_normalizado).strip()
print(texto_normalizado[:500])
#Esto elimina todo espacio doble
# Out:
# Hace ya mucho tiempo en una tierra muy lejana vivia un caballero que pensaba que era bueno generoso y amoroso Hacia todo lo que suelen hacer los caballeros buenos generosos y amorosos Luchaba contra sus enemigos que era malos mezquinos y odiosos Mataba a dragones y rescataba a damiselas en apuros Cuando en el asunto de la caballeria habia crisis tenia la mala costumbre de rescatar damiselas incluso cuando ellas no deseaban ser rescatadas y debido a esto aunque muchas damas le estaban agradecidas

# %%
import spacy
nlp = spacy.load('es_core_news_sm')

# %%
doc = nlp(texto_normalizado)
tokens = [token.text for token in doc if not token.is_stop]
print(tokens[:200])
#Tokenization con spacy
# Out:
# ['tiempo', 'tierra', 'lejana', 'vivia', 'caballero', 'pensaba', 'generoso', 'amoroso', 'suelen', 'caballeros', 'generosos', 'amorosos', 'Luchaba', 'enemigos', 'malos', 'mezquinos', 'odiosos', 'Mataba', 'dragones', 'rescataba', 'damiselas', 'apuros', 'asunto', 'caballeria', 'crisis', 'tenia', 'mala', 'costumbre', 'rescatar', 'damiselas', 'deseaban', 'rescatadas', 'damas', 'agradecidas', 'tantas', 'mostraban', 'furiosas', 'caballero', 'aceptaba', 'filosofia', 'contentar', 'mundo', 'caballero', 'famoso', 'armadura', 'Reflejaba', 'rayos', 'luz', 'brillantes', 'gente', 'pueblo', 'juraba', 'visto', 'sol', 'salir', 'norte', 'ponerse', 'caballero', 'partia', 'batalla', 'partia', 'batalla', 'frecuencia', 'mera', 'mencion', 'cruzada', 'caballero', 'ponia', 'armadura', 'entusiasmado', 'montaba', 'caballo', 'cabalgaba', 'direccion', 'entusiasmo', 'partia', 'direcciones', 'facil', 'anos', 'caballero', 'esforzo', 'numero', 'reino', 'batalla', 'ganar', 'dragon', 'matar', 'damisela', 'rescatar', 'caballero', 'tenia', 'mujer', 'fiel', 'tolerante', 'Julieta', 'escribia', 'hermosos', 'poemas', 'decia', 'cosas', 'inteligentes', 'tenia', 'debilidad', 'vino', 'tenia', 'hijo', 'cabellos', 'dorados', 'Cristobal', 'esperaba', 'algun', 'convertido', 'valiente', 'caballero', 'Julieta', 'Cristobal', 'veian', 'caballero', 'luchando', 'batalla', 'matando', 'dragones', 'rescatando', 'damiselas', 'ocupado', 'probandose', 'armadura', 'admirando', 'brillo', 'tiempo', 'caballero', 'enamoro', 'punto', 'armadura', 'empezo', 'cenar', 'dormir', 'tiempo', 'tomaba', 'molestia', 'quitarsela', 'familia', 'olvidando', 'aspecto', 'tenia', 'Ocasionalmente', 'Cristobal', 'preguntaba', 'madre', 'aspecto', 'tenia', 'padre', 'sucedia', 'Julieta', 'llevaba', 'chico', 'chimenea', 'senalaba', 'retrato', 'caballero', 'padre', 'decia', 'suspiro', 'contemplaba', 'retrato', 'Cristobal', 'madre', 'Ojala', 'pudiera', 'padre', 'persona', 'puedes', 'tenerlo', 'respondio', 'bruscamente', 'Julieta', 'harta', 'pintura', 'recuerdo', 'rostro', 'marido', 'cansada', 'dormir', 'culpa', 'ruido', 'metalico', 'armadura', 'paraba', 'casa', 'absolutamente', 'pendiente', 'armadura', 'caballero', 'solia', 'recitar', 'monologos', 'hazanas', 'Julieta', 'Cristobal', 'podian']

# %%
doc = nlp(texto)
lemas = [token.lemma_ for token in doc if not token.is_punct and not token.is_stop and not token.is_space]
print(lemas[:200])
#Lematizacion
# Out:
# ['tiempo', 'tierra', 'lejano', 'vivir', 'caballero', 'pensar', 'generoso', 'amoroso', 'hacer', 'soler', 'caballero', 'generoso', 'amoroso', 'luchar', 'enemigo', 'malo', 'mezquino', 'odioso', 'matar', 'dragón', 'rescatar', 'dami él él', 'apuro', 'asunto', 'caballería', 'crisis', 'malo', 'costumbre', 'rescatar', 'dami él él', 'desear', 'rescatar', 'dama', 'agradecido', 'tanto', 'mostrar', 'furiosa', 'caballero', 'aceptar', 'filosofía', 'contentar', 'mundo', 'caballero', 'famoso', 'armadura', 'reflejar', 'rayo', 'luz', 'brillante', 'gente', 'pueblo', 'jurar', 'ver', 'sol', 'salir', 'norte', 'poner él', 'caballero', 'partir', 'batalla', 'partir', 'batalla', 'frecuencia', 'mero', 'mención', 'cruzada', 'caballero', 'poner', 'armadura', 'entusiasmado', 'montar', 'caballo', 'cabalgar', 'dirección', 'entusiasmo', 'partir', 'dirección', 'fácil', 'año', 'caballero', 'esforzar', 'número', 'reino', 'batalla', 'ganar', 'dragón', 'matar', 'damisela', 'rescatar', 'caballero', 'mujer', 'fiel', 'tolerante', 'Julieta', 'escribir', 'hermoso', 'poema', 'decir', 'cosa', 'inteligente', 'debilidad', 'vino', 'hijo', 'cabello', 'dorado', 'Cristóbal', 'esperar', 'convertido', 'valiente', 'caballero', 'Julieta', 'Cristóbal', 'ver', 'caballero', 'luchar', 'batalla', 'matar', 'dragón', 'rescatar', 'dami él él', 'ocupado', 'probar él', 'armadura', 'admirar', 'brillo', 'tiempo', 'caballero', 'enamorar', 'punto', 'armadura', 'empezar', 'cenar', 'dormir', 'tiempo', 'tomar', 'molestia', 'quitársela', 'familia', 'olvidar', 'aspecto', 'Ocasionalmente', 'Cristóbal', 'preguntar', 'madre', 'aspecto', 'padre', 'suceder', 'Julieta', 'llevar', 'chico', 'chimenea', 'señalar', 'retrato', 'caballero', 'padre', 'decir', 'suspiro', 'contemplar', 'retrato', 'Cristóbal', 'madre', '-ojalá', 'poder', 'padre', 'persona', '-¡no', 'poder', 'tener él', 'responder', 'bruscamente', 'Julieta', 'hartar', 'pintura', 'recuerdo', 'rostro', 'marido', 'cansar', 'dormir', 'culpa', 'ruido', 'metálico', 'armadura', 'parar', 'casa', 'absolutamente', 'pendiente', 'armadura', 'caballero', 'soler', 'recitar', 'monólogo', 'hazaña', 'Julieta', 'Cristóbal', 'poder', 'palabra', 'hacer', 'caballero', 'acallar', 'cerrar']

# %%
doc = nlp(texto)
for token in doc:
    print(token.pos_)
# Out:
# VERB
# ADV
# DET
# NOUN
# PUNCT
# ADP
# DET
# NOUN
# ADV
# ADJ
# PUNCT
# VERB
# DET
# NOUN
# PRON
# VERB
# SCONJ
# AUX
# ADJ
# PUNCT
# ADJ
# CCONJ
# SPACE
# ADJ
# PUNCT
# VERB
# DET
# PRON
# PRON
# VERB
# VERB
# DET
# NOUN
# ADJ
# PUNCT
# NOUN
# CCONJ
# NOUN
# PUNCT
# VERB
# ADP
# DET
# SPACE
# NOUN
# PUNCT
# PRON
# AUX
# ADJ
# PUNCT
# NOUN
# CCONJ
# NOUN
# PUNCT
# VERB
# ADP
# NOUN
# CCONJ
# VERB
# ADP
# VERB
# ADP
# NOUN
# PUNCT
# SPACE
# SCONJ
# ADP
# DET
# NOUN
# ADP
# DET
# NOUN
# AUX
# NOUN
# PUNCT
# VERB
# DET
# ADJ
# PUNCT
# PUNCT
# PRON
# PRON
# VERB
# ADV
# PUNCT
# SPACE
# PROPN
# VERB
# PUNCT
# SPACE
# PUNCT
# SCONJ
# ADV
# ADJ
# ADV
# PRON
# VERB
# PUNCT
# SCONJ
# DET
# NOUN
# AUX
# ADJ
# PUNCT
# DET
# NOUN
# VERB
# PUNCT
# SPACE
# PUNCT
# INTJ
# PROPN
# VERB
# ADV
# PUNCT
# AUX
# ADP
# VERB
# ADP
# PRON
# PUNCT
# VERB
# DET
# NOUN
# PUNCT
# SPACE
# VERB
# DET
# NOUN
# CCONJ
# PRON
# VERB
# DET
# NOUN
# ADP
# PROPN
# ADP
# NOUN
# ADP
# NOUN
# PUNCT
# CCONJ
# ADP
# ADV
# PRON
# VERB
# DET
# NOUN
# ADP
# NOUN
# SPACE
# ADP
# DET
# NOUN
# PUNCT
# SPACE
# PROPN
# VERB
# DET
# NOUN
# PUNCT
# DET
# NOUN
# VERB
# ADV
# DET
# NOUN
# ADP
# NOUN
# PUNCT
# SPACE
# PUNCT
# PRON
# VERB
# PUNCT
# SPACE
# PROPN
# PRON
# VERB
# DET
# NOUN
# ADJ
# PUNCT
# SPACE
# PUNCT
# SCONJ
# DET
# NOUN
# VERB
# CCONJ
# NOUN
# ADV
# PUNCT
# VERB
# DET
# NOUN
# ADP
# DET
# PRON
# ADV
# PUNCT
# SPACE
# PUNCT
# PUNCT
# PRON
# INTJ
# PUNCT
# PUNCT
# VERB
# DET
# NOUN
# PUNCT
# SPACE
# VERB
# VERB
# DET
# NOUN
# CCONJ
# PUNCT
# VERB
# ADJ
# NOUN
# ADP
# DET
# NOUN
# PUNCT
# PRON
# VERB
# VERB
# PUNCT

# %%
doc = nlp(texto)
Pos_tag = [token.pos_ for token in doc if not token.is_stop and not token.is_punct and not token.is_space]
print(Pos_tag[:200])
# Out:
# ['NOUN', 'NOUN', 'ADJ', 'VERB', 'NOUN', 'VERB', 'ADJ', 'ADJ', 'VERB', 'VERB', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'ADJ', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'VERB', 'VERB', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'VERB', 'VERB', 'VERB', 'VERB', 'NOUN', 'ADJ', 'DET', 'VERB', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'VERB', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'VERB', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'NOUN', 'VERB', 'VERB', 'NOUN', 'VERB', 'NOUN', 'VERB', 'NOUN', 'VERB', 'NOUN', 'VERB', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'ADJ', 'VERB', 'NOUN', 'VERB', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'ADJ', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'VERB', 'NOUN', 'VERB', 'NOUN', 'NOUN', 'ADJ', 'ADJ', 'PROPN', 'VERB', 'NOUN', 'ADJ', 'VERB', 'NOUN', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADJ', 'PROPN', 'VERB', 'ADJ', 'ADJ', 'NOUN', 'PROPN', 'PROPN', 'VERB', 'NOUN', 'VERB', 'NOUN', 'VERB', 'NOUN', 'VERB', 'VERB', 'ADJ', 'VERB', 'NOUN', 'VERB', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'NOUN', 'VERB', 'VERB', 'VERB', 'NOUN', 'VERB', 'NOUN', 'PROPN', 'NOUN', 'VERB', 'NOUN', 'PROPN', 'PROPN', 'VERB', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'PROPN', 'VERB', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'VERB', 'NOUN', 'PROPN', 'NOUN', 'ADV', 'AUX', 'NOUN', 'NOUN', 'NUM', 'AUX', 'VERB', 'VERB', 'ADV', 'PROPN', 'VERB', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'VERB', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'VERB', 'NOUN', 'ADV', 'ADJ', 'NOUN', 'NOUN', 'VERB', 'VERB', 'NOUN', 'NOUN', 'PROPN', 'PROPN', 'AUX', 'NOUN', 'VERB', 'NOUN', 'VERB', 'VERB']

# %%
from spacy import displacy
doc = nlp('Hace ya mucho tiempo, en una tierra muy lejana, vivía un caballero que pensaba que era bueno, generoso y amoroso.')
displacy.serve(doc, style='dep')
# Out:
# c:\Proyectos_DS\nlp-lab\AV_NLP_LAB\Lib\site-packages\spacy\displacy\__init__.py:106: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 3
#       1 from spacy import displacy
#       2 doc = nlp('Hace ya mucho tiempo, en una tierra muy lejana, vivía un caballero que pensaba que era bueno, generoso y amoroso.')
# ----> 3 displacy.serve(doc, style='dep')
#
# File c:\Proyectos_DS\nlp-lab\AV_NLP_LAB\Lib\site-packages\spacy\displacy\__init__.py:107, in serve(docs, style, page, minify, options, manual, port, host, auto_select_port)
#     105 if is_in_jupyter():
#     106     warnings.warn(Warnings.W011)
# --> 107 render(docs, style=style, page=page, minify=minify, options=options, manual=manual)
#     108 httpd = simple_server.make_server(host, port, app)
#     109 print(f"\nUsing the '{style}' visualizer")
#
# File c:\Proyectos_DS\nlp-lab\AV_NLP_LAB\Lib\site-packages\spacy\displacy\__init__.py:69, in render(docs, style, page, minify, jupyter, options, manual)
#      65     html = RENDER_WRAPPER(html)
#      66 if jupyter or (jupyter is None and is_in_jupyter()):
#      67     # return HTML rendered by IPython display()
#      68     # See #4840 for details on span wrapper to disable mathjax
# ---> 69     from IPython.core.display import HTML, display
#      71     return display(HTML('<span class="tex2jax_ignore">{}</span>'.format(html)))
#      72 return html
#
# ImportError: cannot import name 'display' from 'IPython.core.display' (c:\Proyectos_DS\nlp-lab\AV_NLP_LAB\Lib\site-packages\IPython\core\display.py)
